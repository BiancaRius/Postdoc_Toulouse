# %% [markdown]
# # Postdoc - Bianca Rius <h1>

# %% [markdown]
# Created : 22/11/2024
#
# File to track activities to be done, notes from meetings, possible references and etc...
#
# There is also a ppt file with references, expected outcomes and ideas : here is the [link](https://docs.google.com/presentation/d/1J_T31RjmyeHK85Hv6BpBFZg01UCrD6c1zYShmn5LX-I/edit?usp=sharing)

# %% [markdown]
# ##  Meeting with Jerome and Isabelle in 19/11/2024

# %% [markdown]
# ### Meeting Overview

# %% [markdown]
# In this meeting I presented:
# - Some context as an overview on the recent references about Amazon forest and climate change impacts
# - Modeling the Forests of French Guiana: The benefits of employing a fine-individual-scale model
# - Potential Challenges and Key Definitions
# - Anticipated Results and Hypotheses
#
# Jerome and Isabelle made important comments, possible themes for the project and important next steps were defined

# %% [markdown]
# ### Tasks identified in the meeting

# %% [markdown]
# - [ X   ] Verify if there is a gridded product for water table table depth in [Costa et al., 2023](https://nph.onlinelibrary.wiley.com/doi/full/10.1111/nph.17914)
#
#     - Aparently yes, and the product can be found in other [study](https://hess.copernicus.org/articles/14/2039/2010/hess-14-2039-2010.pdf)

# %% [markdown]
# ![Captura de Tela 2024-11-22 às 18.09.28.png](<attachment:Captura de Tela 2024-11-22 às 18.09.28.png>)

# %% [markdown]
# - [  ] Verify how Flavia Costa developed the model the used on [Costa et al., 2023](https://nph.onlinelibrary.wiley.com/doi/full/10.1111/nph.17914)
#     - From what I have seen superficially, she made an review on this paper but she cites other study that made a model
#     - Also, Caio Mattos developed some model?
#     - Philip included WTD on his study?

# %% [markdown]
# ### Possible developments or analysis to be made (still to be completely decided)

# %% [markdown]
# - [ ] One possible steps of my project could be How to include the effect of water table depths: Theory about can be seen in [Costa et al., 2023](https://nph.onlinelibrary.wiley.com/doi/full/10.1111/nph.17914)
#     - Apparently Sylvain have talked to Flavia Costa about this
#     - Possible collaborations/discussions with Manaus group and also French Guiana people
#     - Several studies on this topic have been made in Manaus
#
#
#
# ![Captura de Tela 2024-11-22 às 18.07.47.png](<attachment:Captura de Tela 2024-11-22 às 18.07.47.png>)

# %% [markdown]
# - [   ] Test the importance of representing fine scale processes/properties such as water table depth and topography on modeling French Guiana
#
#
#     - First make it at the stand scale (turning on and off some representations and see how it changes simulated outputs)
#
#
#     - There is still no representation on water table depth in TROLL because we don't have topography
#         - However, there is very good LIDAR data for Paracou and Nouragues with the elevation of the ground level. Based on this information is possible to have a very good information on topography
#             - From this you can construct a basic water table depth model (Jerome thanks that was how Flavia Costa made)

# %% [markdown]
# -
